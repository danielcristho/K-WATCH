# %%
import joblib
feat = joblib.load('../detector/models/feature_names_syscall.pkl')
print(type(feat), len(feat) if hasattr(feat, '__len__') else feat)
print(feat[:5] if hasattr(feat, '__getitem__') else feat)
# Out:
# <class 'list'> 6168
# ['10_10_10_10_10', '10_10_10_10_12', '10_10_10_10_231', '10_10_10_10_257', '10_10_10_10_281']
